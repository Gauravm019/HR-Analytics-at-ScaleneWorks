# %% [raw]
# PART 1 - Data Exploration and Cleaning

# %%
#Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load the Dataset
df = pd.read_excel("C:\\Users\\Bhargav\\OneDrive\\Desktop\\BA\\Machine Learning\\CASE STUDY\\HARWARD CASESTUDY\\Assignment.xlsx")
# Out:
# C:\Users\Bhargav\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
#Display the First 5 Rows
df.head()
# Out:
#    Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# 0        2110407          Yes                      14.0             30
# 1        2112635           No                      18.0             30
# 2        2112838           No                       3.0             45
# 3        2115021           No                      26.0             30
# 4        2115125          Yes                       1.0            120
#
#   Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# ...

# %%
#Check Dataset Shape
df.shape
# Out:
# (12333, 17)

# %%
#Check Column Names
df.columns
# Out:
# Index(['Candidate Ref', 'DOJ Extended', 'Duration to accept offer',
#        'Notice period', 'Offered band', 'Pecent hike expected in CTC',
#        'Percent hike offered in CTC', 'Percent difference CTC',
#        'Joining Bonus', 'Candidate relocate actual', 'Gender',
#        'Candidate Source', 'Rex in Yrs', 'LOB', 'Location', 'Age', 'Status'],
#       dtype='object')

# %%
#Check Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12333 entries, 0 to 12332
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Candidate Ref                12333 non-null  int64
#  1   DOJ Extended                 12333 non-null  object
#  2   Duration to accept offer     9614 non-null   float64
#  3   Notice period                12333 non-null  int64
#  4   Offered band                 12333 non-null  object
#  5   Pecent hike expected in CTC  11586 non-null  float64
#  6   Percent hike offered in CTC  11737 non-null  float64
#  7   Percent difference CTC       11482 non-null  float64
#  8   Joining Bonus                12333 non-null  object
#  9   Candidate relocate actual    12333 non-null  object
#  10  Gender                       12333 non-null  object
#  11  Candidate Source             12333 non-null  object
#  12  Rex in Yrs                   12333 non-null  int64
# ...

# %%
#Summary Statistics
df.describe()
# Out:
#        Candidate Ref  Duration to accept offer  Notice period  \
# count   1.233300e+04               9614.000000   12333.000000
# mean    2.872888e+06                 21.189619      37.943323
# std     5.099726e+05                 26.410351      24.526587
# min     2.109586e+06               -228.000000       0.000000
# 25%     2.378256e+06                  2.000000      30.000000
# 50%     2.820675e+06                  9.000000      30.000000
# 75%     3.338197e+06                 32.000000      60.000000
# max     3.836076e+06                224.000000     120.000000
#
#        Pecent hike expected in CTC  Percent hike offered in CTC  \
# count                 11586.000000                 11737.000000
# mean                     41.837663                    37.772016
# std                      29.435844                    35.593317
# min                     -68.830000                   -60.530000
# 25%                      25.000000                    20.000000
# ...

# %%
#Check Missing Values
df.isnull().sum()
# Out:
# Candidate Ref                     0
# DOJ Extended                      0
# Duration to accept offer       2719
# Notice period                     0
# Offered band                      0
# Pecent hike expected in CTC     747
# Percent hike offered in CTC     596
# Percent difference CTC          851
# Joining Bonus                     0
# Candidate relocate actual         0
# Gender                            0
# Candidate Source                  0
# Rex in Yrs                        0
# LOB                               0
# Location                          0
# Age                               0
# Status                            0
# dtype: int64

# %%
#If there are missing values:
#For numerical columns:
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
#For categorical columns:
df.fillna(df.mode().iloc[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Candidate Ref                  0
# DOJ Extended                   0
# Duration to accept offer       0
# Notice period                  0
# Offered band                   0
# Pecent hike expected in CTC    0
# Percent hike offered in CTC    0
# Percent difference CTC         0
# Joining Bonus                  0
# Candidate relocate actual      0
# Gender                         0
# Candidate Source               0
# Rex in Yrs                     0
# LOB                            0
# Location                       0
# Age                            0
# Status                         0
# dtype: int64

# %%
#Check Duplicate Records
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Check Unique Values
df.nunique()
# Out:
# Candidate Ref                  12333
# DOJ Extended                       2
# Duration to accept offer         147
# Notice period                      7
# Offered band                       7
# Pecent hike expected in CTC     2517
# Percent hike offered in CTC     3188
# Percent difference CTC          1456
# Joining Bonus                      2
# Candidate relocate actual          2
# Gender                             2
# Candidate Source                   3
# Rex in Yrs                        25
# LOB                               12
# Location                          12
# Age                               36
# Status                             2
# dtype: int64

# %%
#Check Target Variable
df["Status"].value_counts()
# Out:
# Status
# Joined        8725
# Not Joined    3608
# Name: count, dtype: int64

# %%
#Check Percentage
df["Status"].value_counts(normalize=True)*100
# Out:
# Status
# Joined        70.745155
# Not Joined    29.254845
# Name: proportion, dtype: float64

# %%
#Remove Unnecessary Column
df.drop("Candidate Ref", axis=1, inplace=True)

# %%
#Final Dataset Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12333 entries, 0 to 12332
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DOJ Extended                 12333 non-null  object
#  1   Duration to accept offer     12333 non-null  float64
#  2   Notice period                12333 non-null  int64
#  3   Offered band                 12333 non-null  object
#  4   Pecent hike expected in CTC  12333 non-null  float64
#  5   Percent hike offered in CTC  12333 non-null  float64
#  6   Percent difference CTC       12333 non-null  float64
#  7   Joining Bonus                12333 non-null  object
#  8   Candidate relocate actual    12333 non-null  object
#  9   Gender                       12333 non-null  object
#  10  Candidate Source             12333 non-null  object
#  11  Rex in Yrs                   12333 non-null  int64
#  12  LOB                          12333 non-null  object
# ...

# %% [raw]
# PART 2 - Exploratory Data Analysis (EDA)

# %%
#1. Status Distribution (Target Variable) 
#This chart shows how many candidates joined and how many did not.

#Without Numbers
#df["Status"].value_counts().plot(kind="bar")
#plt.title("Status Distribution")
#plt.xlabel("Status")
#plt.ylabel("Count")
#plt.show()

#With Numbers
status = df["Status"].value_counts()

ax = status.plot(kind="bar")

plt.title("Status Distribution")
plt.xlabel("Status")
plt.ylabel("Count")

for i in ax.patches:
    ax.annotate(str(i.get_height()),
                (i.get_x() + i.get_width()/2, i.get_height()),
                ha='center',
                va='bottom')

plt.show()

# %%
# 2. Gender Distribution

#Without Numbers
#df["Gender"].value_counts().plot(kind="bar")
#plt.title("Gender Distribution")
#plt.xlabel("Gender")
#plt.ylabel("Count")
#plt.show()

#With Numbers
gender = df["Gender"].value_counts()

ax = gender.plot(kind="bar")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

for i in ax.patches:
    ax.annotate(str(i.get_height()),
                (i.get_x()+i.get_width()/2, i.get_height()),
                ha='center',
                va='bottom')

plt.show()

# %%
# 3. Candidate Source
#Without Numbers
#df["Candidate Source"].value_counts().plot(kind="bar")
#plt.title("Candidate Source")
#plt.xlabel("Source")
#plt.ylabel("Count")
#plt.show()

#With Numbers
source = df["Candidate Source"].value_counts()

ax = source.plot(kind="bar")

plt.title("Candidate Source")
plt.xlabel("Candidate Source")
plt.ylabel("Count")

for i in ax.patches:
    ax.annotate(str(i.get_height()),
                (i.get_x()+i.get_width()/2, i.get_height()),
                ha='center',
                va='bottom')

plt.show()

# %%
# 4. DOJ Extended
#Without Numbers
#df["DOJ Extended"].value_counts().plot(kind="bar")
#plt.title("DOJ Extended")
#plt.xlabel("DOJ Extended")
#plt.ylabel("Count")
#plt.show()

#With Numbers
doj = df["DOJ Extended"].value_counts()

ax = doj.plot(kind="bar")

plt.title("DOJ Extended")
plt.xlabel("DOJ Extended")
plt.ylabel("Count")

for i in ax.patches:
    ax.annotate(str(i.get_height()),
                (i.get_x()+i.get_width()/2, i.get_height()),
                ha='center',
                va='bottom')

plt.show()

# %%
#5. Joining Bonus

#Without Numbers
#df["Joining Bonus"].value_counts().plot(kind="bar")
#plt.title("Joining Bonus")
#plt.xlabel("Joining Bonus")
#plt.ylabel("Count")
#plt.show()

#With Numbers
bonus = df["Joining Bonus"].value_counts()

ax = bonus.plot(kind="bar")

plt.title("Joining Bonus")
plt.xlabel("Joining Bonus")
plt.ylabel("Count")

for i in ax.patches:
    ax.annotate(str(i.get_height()),
                (i.get_x()+i.get_width()/2, i.get_height()),
                ha='center',
                va='bottom')

plt.show()

# %%
#6. Notice Period

plt.figure(figsize=(7,5))

plt.hist(df["Notice period"], bins=15, edgecolor="black")

plt.title("Notice Period Distribution")
plt.xlabel("Notice Period")
plt.ylabel("Frequency")

plt.show()

# %%
#7. Age Distribution
plt.figure(figsize=(7,5))

plt.hist(df["Age"], bins=10, edgecolor="black")

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
#8. Correlation Heatmap
import seaborn as sns

numeric_df = df.select_dtypes(include=["int64","float64"])

plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %% [raw]
# Part 3 : Data Preprocessing

# %%
#Import Required Library
from sklearn.preprocessing import LabelEncoder

#Create Label Encoder
le = LabelEncoder()

# %%
#Convert Categorical Columns into Numbers
categorical_columns = [
    "DOJ Extended",
    "Offered band",
    "Joining Bonus",
    "Candidate relocate actual",
    "Gender",
    "Candidate Source",
    "LOB",
    "Location",
    "Status"
]

for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    DOJ Extended  Duration to accept offer  Notice period  Offered band  \
# 0             1                      14.0             30             2
# 1             0                      18.0             30             2
# 2             0                       3.0             45             2
# 3             0                      26.0             30             2
# 4             1                       1.0            120             2
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC  Joining Bonus  Candidate relocate actual  Gender  \
# 0                   42.86              0                          0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12333 entries, 0 to 12332
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DOJ Extended                 12333 non-null  int64
#  1   Duration to accept offer     12333 non-null  float64
#  2   Notice period                12333 non-null  int64
#  3   Offered band                 12333 non-null  int64
#  4   Pecent hike expected in CTC  12333 non-null  float64
#  5   Percent hike offered in CTC  12333 non-null  float64
#  6   Percent difference CTC       12333 non-null  float64
#  7   Joining Bonus                12333 non-null  int64
#  8   Candidate relocate actual    12333 non-null  int64
#  9   Gender                       12333 non-null  int64
#  10  Candidate Source             12333 non-null  int64
#  11  Rex in Yrs                   12333 non-null  int64
#  12  LOB                          12333 non-null  int64
# ...

# %%
#Separate Features (X) and Target (y)
#The Status column is what we want to predict.

X = df.drop("Status", axis=1)

y = df["Status"]

# %%
#Check Features and Target
print(X.head())
# Out:
#    DOJ Extended  Duration to accept offer  Notice period  Offered band  \
# 0             1                      14.0             30             2
# 1             0                      18.0             30             2
# 2             0                       3.0             45             2
# 3             0                      26.0             30             2
# 4             1                       1.0            120             2
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC  Joining Bonus  Candidate relocate actual  Gender  \
# 0                   42.86              0                          0       0
# ...

# %%
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Status, dtype: int64

# %%
#Split the Dataset
#We'll use:
    #80% for training
    #20% for testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)

# %%
#Check the Shapes
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (9866, 15)
# (2467, 15)
# (9866,)
# (2467,)

# %% [raw]
# Part 4: Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [raw]
# Model 1: Logistic Regression

# %%
#Train the Model
lr = LogisticRegression(max_iter=1000)

lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Predict
y_pred_lr = lr.predict(X_test)

# %%
#Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Accuracy: 0.7482772598297527

# %%
#Confusion Matrix
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# [[1597  143]
#  [ 478  249]]

# %%
#Classification Report
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      1740
#            1       0.64      0.34      0.45       727
#
#     accuracy                           0.75      2467
#    macro avg       0.70      0.63      0.64      2467
# weighted avg       0.73      0.75      0.72      2467

# %% [raw]
# Model 2: Decision Tree

# %%
#Train
dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#Predict
y_pred_dt = dt.predict(X_test)

# %%
#Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Accuracy: 0.7802999594649371

# %%
#Confusion Matrix
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# [[1466  274]
#  [ 268  459]]

# %%
#Classification Report
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      1740
#            1       0.63      0.63      0.63       727
#
#     accuracy                           0.78      2467
#    macro avg       0.74      0.74      0.74      2467
# weighted avg       0.78      0.78      0.78      2467

# %% [raw]
# Model 3: Random Forest

# %%
#Train
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Predict
y_pred_rf = rf.predict(X_test)

# %%
#Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy: 0.83664369679773

# %%
#Confusion Matrix
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# [[1656   84]
#  [ 319  408]]

# %%
#Classification Report
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      1740
#            1       0.83      0.56      0.67       727
#
#     accuracy                           0.84      2467
#    macro avg       0.83      0.76      0.78      2467
# weighted avg       0.84      0.84      0.83      2467

# %%
#Compare All Models
lr_acc = accuracy_score(y_test, y_pred_lr)
dt_acc = accuracy_score(y_test, y_pred_dt)
rf_acc = accuracy_score(y_test, y_pred_rf)

print("Logistic Regression :", lr_acc)
print("Decision Tree       :", dt_acc)
print("Random Forest       :", rf_acc)
# Out:
# Logistic Regression : 0.7482772598297527
# Decision Tree       : 0.7802999594649371
# Random Forest       : 0.83664369679773

# %%
#Better Comparison (Table)
results = pd.DataFrame({
    "Model": ["Logistic Regression", "Decision Tree", "Random Forest"],
    "Accuracy": [lr_acc, dt_acc, rf_acc]
})

print(results)
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.748277
# 1        Decision Tree  0.780300
# 2        Random Forest  0.836644

# %% [raw]
# Part 5: Feature Importance (Key Drivers)

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(by="Importance", ascending=False)

print(importance)
# Out:
#                         Feature  Importance
# 1      Duration to accept offer    0.192198
# 6        Percent difference CTC    0.119446
# 5   Percent hike offered in CTC    0.105367
# 4   Pecent hike expected in CTC    0.098088
# 2                 Notice period    0.071605
# 14                          Age    0.066851
# 11                   Rex in Yrs    0.065105
# 8     Candidate relocate actual    0.062214
# 12                          LOB    0.061559
# 13                     Location    0.040599
# 0                  DOJ Extended    0.036666
# 3                  Offered band    0.031008
# 10             Candidate Source    0.027490
# 9                        Gender    0.014833
# 7                 Joining Bonus    0.006972

# %%
plt.figure(figsize=(8,6))

plt.barh(importance["Feature"], importance["Importance"])

plt.title("Feature Importance")
plt.xlabel("Importance")
plt.ylabel("Features")

plt.show()
